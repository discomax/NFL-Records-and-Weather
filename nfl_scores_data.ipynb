# %%
# This code is for opening, reading and processing historical nfl scores data

import pandas as pd
import numpy as np
import requests
import time
import datetime
import csv
from pprint import pprint

# Import API key
from mike_api import api_key
# create the object to load from the file

# File to Load (Remember to change these)
nfl_data_toload = "spreadspoke_scores.csv"

# read the data
nfl_data = pd.read_csv(nfl_data_toload)
nfl_data.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    09/02/1966             1966             1             False
# 1    09/03/1966             1966             1             False
# 2    09/04/1966             1966             1             False
# 3    09/09/1966             1966             2             False
# 4    09/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# ...

# %%
# clean up the data
# remove dates prior to prior to 2013 but not after 2017
# remove playoff games
nfl_after_2013 = nfl_data[nfl_data.schedule_season > 2013]
nfl_before_2018 = nfl_after_2013[nfl_after_2013.schedule_season < 2018]
nfl_no_playoffs = nfl_before_2018[nfl_before_2018.schedule_playoff != True]
nfl_no_playoffs.head()
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 11076    09/04/2014             2014             1             False
# 11077    09/07/2014             2014             1             False
# 11078    09/07/2014             2014             1             False
# 11079    09/07/2014             2014             1             False
# 11080    09/07/2014             2014             1             False
#
#               team_home  score_home  score_away            team_away  \
# 11076  Seattle Seahawks        36.0        16.0    Green Bay Packers
# 11077   Atlanta Falcons        37.0        34.0   New Orleans Saints
# 11078  Baltimore Ravens        16.0        23.0   Cincinnati Bengals
# 11079     Chicago Bears        20.0        23.0        Buffalo Bills
# 11080    Dallas Cowboys        17.0        28.0  San Francisco 49ers
#
#       team_favorite_id  spread_favorite over_under_line            stadium  \
# ...

# %%
# drop uneeded columns
nfl_data_clean = nfl_no_playoffs.drop(nfl_data.columns[[2, 3, 7, 8, 9, 10, 12, 13, 14, 15, 16]], axis=1)
nfl_data_clean.head()
# Out:
#       schedule_date  schedule_season         team_home  score_home  \
# 11076    09/04/2014             2014  Seattle Seahawks        36.0
# 11077    09/07/2014             2014   Atlanta Falcons        37.0
# 11078    09/07/2014             2014  Baltimore Ravens        16.0
# 11079    09/07/2014             2014     Chicago Bears        20.0
# 11080    09/07/2014             2014    Dallas Cowboys        17.0
#
#        score_away            stadium
# 11076        16.0  CenturyLink Field
# 11077        34.0       Georgia Dome
# 11078        23.0   M&T Bank Stadium
# 11079        23.0      Soldier Field
# 11080        28.0    Cowboys Stadium

# %%
# determine if home team won
# define a function to calculate if the home team wom or loss
def winLoss (row):
    num1 = row['score_home']
    num2 = row['score_away']
    if num1 - num2 > 0:
        return 'W'
    return 'L'

# %%
# use winLoss() function to create new win/loss column showing result of game and write to csv

nfl_data_clean['win/loss'] = nfl_data_clean.apply (lambda row: winLoss (row),axis=1)
nfl_data_clean.to_csv('nfl_data.csv')
nfl_data_clean.head()
# Out:
#       schedule_date  schedule_season         team_home  score_home  \
# 11076    09/04/2014             2014  Seattle Seahawks        36.0
# 11077    09/07/2014             2014   Atlanta Falcons        37.0
# 11078    09/07/2014             2014  Baltimore Ravens        16.0
# 11079    09/07/2014             2014     Chicago Bears        20.0
# 11080    09/07/2014             2014    Dallas Cowboys        17.0
#
#        score_away            stadium win/loss
# 11076        16.0  CenturyLink Field        W
# 11077        34.0       Georgia Dome        W
# 11078        23.0   M&T Bank Stadium        L
# 11079        23.0      Soldier Field        L
# 11080        28.0    Cowboys Stadium        L

# %%
nfl_data_clean['schedule_season'].unique()
# Out:
# array([2014, 2015, 2016, 2017])

# %%
# append the geoprahic location for each 

# run a test with a single historical date to see result
cityid = "charlotte"
game_date = '09/04/2014'
start = time.mktime(datetime.datetime.strptime(game_date, "%d/%m/%Y").timetuple())
url = HTTPS: https://api.worldweatheronline.com/premium/v1/past-weather.ashx


units = "imperial"
country = "US"

format_url = f"{url}appid={api_key}&units={units}&type=hour&start={start}&q="
query_url = f"{format_url}{cityid},{country}"

response = requests.get(query_url).json()
response
# Out:
# {'cod': 401,
#  'message': 'Invalid API key. Please see http://openweathermap.org/faq#error401 for more info.'}
