# %%
# This code is for opening, reading and processing historical nfl scores data

import pandas as pd
import numpy as np
# create the object to load from the file

# File to Load (Remember to change these)
nfl_data_toload = "spreadspoke_scores.csv"

# read the data
nfl_data = pd.read_csv(nfl_data_toload)
nfl_data.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0    09/02/1966             1966             1             False
# 1    09/03/1966             1966             1             False
# 2    09/04/1966             1966             1             False
# 3    09/09/1966             1966             2             False
# 4    09/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# ...

# %%
# clean up the data
# remove dates prior to 2010
nfl_data = nfl_data[nfl_data.schedule_season > 2010]
nfl_data.head()
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 10275    09/08/2011             2011             1             False
# 10276    09/11/2011             2011             1             False
# 10277    09/11/2011             2011             1             False
# 10278    09/11/2011             2011             1             False
# 10279    09/11/2011             2011             1             False
#
#                team_home  score_home  score_away            team_away  \
# 10275  Green Bay Packers        42.0        34.0   New Orleans Saints
# 10276  Arizona Cardinals        28.0        21.0    Carolina Panthers
# 10277   Baltimore Ravens        35.0         7.0  Pittsburgh Steelers
# 10278      Chicago Bears        30.0        12.0      Atlanta Falcons
# 10279   Cleveland Browns        17.0        27.0   Cincinnati Bengals
#
#       team_favorite_id  spread_favorite over_under_line  \
# 10275               GB             -5.0              48
# ...

# %%
# drop uneeded columns
nfl_data.drop(nfl_data.columns[[2, 3, 7, 8, 9, 10, 12, 13, 14, 15, 16]], inplace=True, axis=1)
nfl_data.head()
# Out:
#       schedule_date  schedule_season          team_home  score_home  \
# 10275    09/08/2011             2011  Green Bay Packers        42.0
# 10276    09/11/2011             2011  Arizona Cardinals        28.0
# 10277    09/11/2011             2011   Baltimore Ravens        35.0
# 10278    09/11/2011             2011      Chicago Bears        30.0
# 10279    09/11/2011             2011   Cleveland Browns        17.0
#
#        score_away                        stadium
# 10275        34.0                  Lambeau Field
# 10276        21.0  University of Phoenix Stadium
# 10277         7.0               M&T Bank Stadium
# 10278        12.0                  Soldier Field
# 10279        27.0            FirstEnergy Stadium

# %%
# determine if home team won
# define a function to calculate if the home team wom or loss
def winLoss (row):
    num1 = row['score_home']
    num2 = row['score_away']
    if num1 - num2 > 0:
        return 'W'
    return 'L'

# %%
# use winLoss() function to create new win/loss column showing result of game

nfl_data['win/loss'] = nfl_data.apply (lambda row: winLoss (row),axis=1)
nfl_data.head()
# Out:
#       schedule_date  schedule_season          team_home  score_home  \
# 10275    09/08/2011             2011  Green Bay Packers        42.0
# 10276    09/11/2011             2011  Arizona Cardinals        28.0
# 10277    09/11/2011             2011   Baltimore Ravens        35.0
# 10278    09/11/2011             2011      Chicago Bears        30.0
# 10279    09/11/2011             2011   Cleveland Browns        17.0
#
#        score_away                        stadium win/loss
# 10275        34.0                  Lambeau Field        W
# 10276        21.0  University of Phoenix Stadium        W
# 10277         7.0               M&T Bank Stadium        W
# 10278        12.0                  Soldier Field        W
# 10279        27.0            FirstEnergy Stadium        L

# %%
# make call to weather map
