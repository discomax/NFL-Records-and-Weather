# %%
# Dependencies
import pandas as pd
import csv
import requests
import json

# %%
with open("stadiums_nfl.json") as datafile:
  data = json.load(datafile)
dataframe = pd.DataFrame(data)

# %%
dataframe.head()
# Out:
#       datasetid                                             fields  \
# 0  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
# 1  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
# 2  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
# 3  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
# 4  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
#
#                                             geometry  \
# 0  {'type': 'Point', 'coordinates': [-87.61676997...
# 1  {'type': 'Point', 'coordinates': [-95.41091997...
# 2  {'type': 'Point', 'coordinates': [-94.48388009...
# 3  {'type': 'Point', 'coordinates': [-90.08127999...
# 4  {'type': 'Point', 'coordinates': [-80.23888995...
#
#             record_timestamp                                  recordid
# 0  2017-04-13T04:48:16-04:00  acaab7736b25dbc81055f02ceb96041ea791aab6
# 1  2017-04-13T04:48:16-04:00  b6b73850e7110b440b11ba18a3d5d18c4a4df399
# 2  2017-04-13T04:48:16-04:00  dae0180f6c4107dbc52ea4174d0e331e135d8e74
# 3  2017-04-13T04:48:16-04:00  bb9e7a8c6e5b57f863029203999e7fe3877b50ed
# 4  2017-04-13T04:48:16-04:00  2c453332d4240ec71639594550cd223109270786

# %%
# Store filepath in a variable
file_one = "stadiums_nfl.csv"
file_two = "nfl_data.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
stadiums_nfl_df = pd.read_csv(file_one, encoding="ISO-8859-1")
stadiums_score_df = pd.read_csv(file_two)

# %%
# Show just the header
stadiums_nfl_df.head()
# Out:
#         CITY STATE                     NAME               TEAM    ROOF_TYPE  \
# 0  Arlington    TX          Cowboys Stadium     Dallas Cowboys  Retractable
# 1    Atlanta    GA             Georgia Dome    Atlanta Falcons         Dome
# 2  Baltimore    MD         M&T Bank Stadium   Baltimore Ravens         Open
# 3  Charlotte    NC  Bank of America Stadium  Carolina Panthers         Open
# 4    Chicago    IL            Soldier Field      Chicago Bears         Open
#
#   CONFERENCE DIVISION  CAPACITY  LATITUDE  LONGITUDE     COLOR 1    COLOR 2
# 0   National     East   80000.0  32.74778  -97.09277  ROYAL BLUE        NaN
# 1   National    South   71228.0  33.75735  -84.40121         NaN        NaN
# 2   American    North   71008.0  39.27790  -76.62270         NaN        NaN
# 3   National    South   73778.0  35.22584  -80.85331         NaN        NaN
# 4   National    North   61500.0  41.86250  -87.61677         NaN        NaN

# %%
stadiums_score_df.head()
# Out:
#    Unnamed: 0 schedule_date  schedule_season         team_home  score_home  \
# 0       11076    09/04/2014             2014  Seattle Seahawks        36.0
# 1       11077    09/07/2014             2014   Atlanta Falcons        37.0
# 2       11078    09/07/2014             2014  Baltimore Ravens        16.0
# 3       11079    09/07/2014             2014     Chicago Bears        20.0
# 4       11080    09/07/2014             2014    Dallas Cowboys        17.0
#
#    score_away            stadium win/loss
# 0        16.0  CenturyLink Field        W
# 1        34.0       Georgia Dome        W
# 2        23.0   M&T Bank Stadium        L
# 3        23.0      Soldier Field        L
# 4        28.0    Cowboys Stadium        L

# %%
# Using .rename(columns={}) in order to rename columns
stadiums_score_team_df = stadiums_score_df.rename(columns={"team_home":"TEAM", "score_home":" Score Home", "score_away":"Score Away" })
stadiums_score_team_df.head()
# Out:
#    Unnamed: 0 schedule_date  schedule_season              TEAM   Score Home  \
# 0       11076    09/04/2014             2014  Seattle Seahawks         36.0
# 1       11077    09/07/2014             2014   Atlanta Falcons         37.0
# 2       11078    09/07/2014             2014  Baltimore Ravens         16.0
# 3       11079    09/07/2014             2014     Chicago Bears         20.0
# 4       11080    09/07/2014             2014    Dallas Cowboys         17.0
#
#    Score Away            stadium win/loss
# 0        16.0  CenturyLink Field        W
# 1        34.0       Georgia Dome        W
# 2        23.0   M&T Bank Stadium        L
# 3        23.0      Soldier Field        L
# 4        28.0    Cowboys Stadium        L

# %%
# Show mulitple specific columns--note the extra brackets
stadiums_nfl_df_type = stadiums_nfl_df [["CITY","TEAM" ,"ROOF_TYPE","CAPACITY","LATITUDE","LONGITUDE"]]
stadiums_nfl_df_type.head()
# Out:
#         CITY               TEAM    ROOF_TYPE  CAPACITY  LATITUDE  LONGITUDE
# 0  Arlington     Dallas Cowboys  Retractable   80000.0  32.74778  -97.09277
# 1    Atlanta    Atlanta Falcons         Dome   71228.0  33.75735  -84.40121
# 2  Baltimore   Baltimore Ravens         Open   71008.0  39.27790  -76.62270
# 3  Charlotte  Carolina Panthers         Open   73778.0  35.22584  -80.85331
# 4    Chicago      Chicago Bears         Open   61500.0  41.86250  -87.61677

# %%
# Merge two dataframes using a right join
merge_stadiums_df = pd.merge(stadiums_nfl_df_type, stadiums_score_team_df, on="TEAM", how="right")
merge_stadiums_df
# Out:
#            CITY                  TEAM    ROOF_TYPE  CAPACITY  LATITUDE  \
# 0     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 1     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 2     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 3     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 4     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 5     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 6     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 7     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 8     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 9     Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 10    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 11    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 12    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 13    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 14    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 15    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 16    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 17    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 18    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 19    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 20    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 21    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 22    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 23    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 24    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 25    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 26    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 27    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 28    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# 29    Arlington        Dallas Cowboys  Retractable   80000.0  32.74778
# ...         ...                   ...          ...       ...       ...
# 994         NaN       New York Giants          NaN       NaN       NaN
# 995         NaN       New York Giants          NaN       NaN       NaN
# 996         NaN       New York Giants          NaN       NaN       NaN
# 997         NaN       New York Giants          NaN       NaN       NaN
# 998         NaN       New York Giants          NaN       NaN       NaN
# 999         NaN       New York Giants          NaN       NaN       NaN
# 1000        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1001        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1002        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1003        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1004        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1005        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1006        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1007        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1008        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1009        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1010        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1011        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1012        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1013        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1014        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1015        NaN      Los Angeles Rams          NaN       NaN       NaN
# 1016        NaN  Los Angeles Chargers          NaN       NaN       NaN
# 1017        NaN  Los Angeles Chargers          NaN       NaN       NaN
# 1018        NaN  Los Angeles Chargers          NaN       NaN       NaN
# 1019        NaN  Los Angeles Chargers          NaN       NaN       NaN
# 1020        NaN  Los Angeles Chargers          NaN       NaN       NaN
# 1021        NaN  Los Angeles Chargers          NaN       NaN       NaN
# 1019        NaN       11974    10/22/2017             2017         21.0
# 1020        NaN       12030    11/19/2017             2017         54.0
# 1021        NaN       12061    12/03/2017             2017         19.0
# 1022        NaN       12079    12/10/2017             2017         30.0
# 1023        NaN       12122    12/31/2017             2017         30.0
#
#       Score Away                        stadium win/loss
# 0           28.0                Cowboys Stadium        L
# 1           17.0                Cowboys Stadium        W
# 2           17.0                Cowboys Stadium        W
# 3           21.0                Cowboys Stadium        W
# 4           20.0                Cowboys Stadium        L
# 5           28.0                Cowboys Stadium        L
# 6           33.0                Cowboys Stadium        L
# 7            7.0                Cowboys Stadium        W
# 8           26.0                Cowboys Stadium        W
# 9           39.0                Cowboys Stadium        L
# 10          30.0                Cowboys Stadium        L
# 11          13.0                Cowboys Stadium        L
# 12          33.0                Cowboys Stadium        L
# 13          33.0                Cowboys Stadium        L
# 14          19.0                Cowboys Stadium        L
# 15          34.0                Cowboys Stadium        L
# 16          20.0                Cowboys Stadium        L
# 17          17.0                Cowboys Stadium        W
# 18          14.0                Cowboys Stadium        W
# 19          23.0                Cowboys Stadium        W
# 20          17.0                Cowboys Stadium        W
# 21          26.0                Cowboys Stadium        W
# 22          20.0                Cowboys Stadium        W
# 23          21.0                Cowboys Stadium        W
# 24           3.0                   AT&T Stadium        W
# 25          35.0                   AT&T Stadium        L
# 26          35.0                   AT&T Stadium        L
# 27          17.0                   AT&T Stadium        W
# 28          37.0                   AT&T Stadium        L
# 29          28.0                   AT&T Stadium        L
# ...          ...                            ...      ...
# 994         24.0                MetLife Stadium        L
# 995         51.0                MetLife Stadium        L
# 996          9.0                MetLife Stadium        W
# 997         30.0                MetLife Stadium        L
# 998         34.0                MetLife Stadium        L
# 999         10.0                MetLife Stadium        W
# 1000         3.0  Los Angeles Memorial Coliseum        W
# 1001        30.0  Los Angeles Memorial Coliseum        L
# 1002        17.0             Twickenham Stadium        L
# 1003        13.0  Los Angeles Memorial Coliseum        L
# 1004        14.0  Los Angeles Memorial Coliseum        L
# 1005        42.0  Los Angeles Memorial Coliseum        L
# 1006        22.0  Los Angeles Memorial Coliseum        L
# 1007        44.0  Los Angeles Memorial Coliseum        L
# 1008         9.0  Los Angeles Memorial Coliseum        W
# 1009        27.0  Los Angeles Memorial Coliseum        L
# 1010        16.0  Los Angeles Memorial Coliseum        L
# 1011         0.0             Twickenham Stadium        W
# 1012         7.0  Los Angeles Memorial Coliseum        W
# 1013        20.0  Los Angeles Memorial Coliseum        W
# 1014        43.0  Los Angeles Memorial Coliseum        L
# 1015        34.0  Los Angeles Memorial Coliseum        L
# 1016        19.0                 StubHub Center        L
# 1017        24.0                 StubHub Center        L
# 1018        26.0                 StubHub Center        L
# 1019         0.0                 StubHub Center        W
# 1020        24.0                 StubHub Center        W
# 1021        10.0                 StubHub Center        W
# 1022        13.0                 StubHub Center        W
# 1023        10.0                 StubHub Center        W
#
# [1024 rows x 13 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
stadiums_nfl_df_type.to_csv("stadiums_nfl_type.csv", index=False, header=True)

# %%
# Export file as a CSV, without the Pandas index, but with the header
merge_stadiums_df.to_csv("stadiums_nfl_merge.csv", index=False, header=True)
