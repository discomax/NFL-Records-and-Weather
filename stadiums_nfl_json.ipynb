# %%
# Dependencies
import pandas as pd
import csv
import requests
import json

# %%
with open("stadiums_nfl.json") as datafile:
  data = json.load(datafile)
dataframe = pd.DataFrame(data)

# %%
dataframe.head()
# Out:
#       datasetid                                             fields  \
# 0  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
# 1  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
# 2  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
# 3  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
# 4  stadiums_nfl  {'sector': 'High Value/Symboli', 'reliabilit':...
#
#                                             geometry  \
# 0  {'type': 'Point', 'coordinates': [-87.61676997...
# 1  {'type': 'Point', 'coordinates': [-95.41091997...
# 2  {'type': 'Point', 'coordinates': [-94.48388009...
# 3  {'type': 'Point', 'coordinates': [-90.08127999...
# 4  {'type': 'Point', 'coordinates': [-80.23888995...
#
#             record_timestamp                                  recordid
# 0  2017-04-13T04:48:16-04:00  acaab7736b25dbc81055f02ceb96041ea791aab6
# 1  2017-04-13T04:48:16-04:00  b6b73850e7110b440b11ba18a3d5d18c4a4df399
# 2  2017-04-13T04:48:16-04:00  dae0180f6c4107dbc52ea4174d0e331e135d8e74
# 3  2017-04-13T04:48:16-04:00  bb9e7a8c6e5b57f863029203999e7fe3877b50ed
# 4  2017-04-13T04:48:16-04:00  2c453332d4240ec71639594550cd223109270786

# %%
# Store filepath in a variable
file_one = "stadiums_nfl.csv"
file_two = "nfl_data.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
stadiums_nfl_df = pd.read_csv(file_one, encoding="ISO-8859-1")
stadiums_score_df = pd.read_csv(file_two)

# %%
# Show just the header
stadiums_nfl_df.head()
# Out:
#             CITY STATE REGION                             NAME  \
# 0       Glendale    AZ   West    University of Phoenix Stadium
# 1        Oakland    CA   West  Oakland-Alameda County Coliseum
# 2      San Diego    CA   West                 Qualcomm Stadium
# 3  San Francisco    CA   West                 Candlestick Park
# 4         Denver    CO   West       Invesco Field at Mile High
#
#                   TEAM    ROOF_TYPE CONFERENCE DIVISION  CAPACITY  LATITUDE  \
# 0    Arizona Cardinals  Retractable   National     West   63400.0  33.52713
# 1      Oakland Raiders         Open   American     West   63026.0  37.75233
# 2   San Diego Chargers         Open   American     West   71294.0  32.78322
# 3  San Francisco 49ers         Open   National     West   70207.0  37.71399
# 4       Denver Broncos         Open   American     West   76125.0  39.74396
#
#    LONGITUDE COLOR 1     COLOR 2
# 0 -112.25876   black      yellow
# 1 -122.19990  silver         NaN
# 2 -117.11976    gold  dodgerblue
# 3 -122.38673    gold         NaN
# 4 -105.02028    navy         NaN

# %%
stadiums_score_df.head()
# Out:
#    Unnamed: 0 schedule_date  schedule_season         team_home  score_home  \
# 0       11076    09/04/2014             2014  Seattle Seahawks        36.0
# 1       11077    09/07/2014             2014   Atlanta Falcons        37.0
# 2       11078    09/07/2014             2014  Baltimore Ravens        16.0
# 3       11079    09/07/2014             2014     Chicago Bears        20.0
# 4       11080    09/07/2014             2014    Dallas Cowboys        17.0
#
#    score_away            stadium win/loss
# 0        16.0  CenturyLink Field        W
# 1        34.0       Georgia Dome        W
# 2        23.0   M&T Bank Stadium        L
# 3        23.0      Soldier Field        L
# 4        28.0    Cowboys Stadium        L

# %%
# Using .rename(columns={}) in order to rename columns
stadiums_score_df_2 = stadiums_score_df.rename(columns={"team_home":"TEAM", "score_home":" score Home", "score_away":"Score Away" })
stadiums_score_df_2.head()
# Out:
#    Unnamed: 0 schedule_date  schedule_season              TEAM   score Home  \
# 0       11076    09/04/2014             2014  Seattle Seahawks         36.0
# 1       11077    09/07/2014             2014   Atlanta Falcons         37.0
# 2       11078    09/07/2014             2014  Baltimore Ravens         16.0
# 3       11079    09/07/2014             2014     Chicago Bears         20.0
# 4       11080    09/07/2014             2014    Dallas Cowboys         17.0
#
#    Score Away            stadium win/loss
# 0        16.0  CenturyLink Field        W
# 1        34.0       Georgia Dome        W
# 2        23.0   M&T Bank Stadium        L
# 3        23.0      Soldier Field        L
# 4        28.0    Cowboys Stadium        L

# %%
stadiums_score_df.columns
# Out:
# Index(['Unnamed: 0', 'schedule_date', 'schedule_season', 'team_home',
#        'score_home', 'score_away', 'stadium', 'win/loss'],
#       dtype='object')

# %%
stadiums_nfl_df.columns
# Out:
# Index(['CITY', 'STATE', 'REGION', 'NAME', 'TEAM', 'ROOF_TYPE', 'CONFERENCE',
#        'DIVISION', 'CAPACITY', 'LATITUDE', 'LONGITUDE', 'COLOR 1', 'COLOR 2'],
#       dtype='object')

# %%
# Show mulitple specific columns--note the extra brackets
stadiums_nfl_type_df = stadiums_nfl_df [["CITY","TEAM" ,"ROOF_TYPE","CAPACITY","LATITUDE","LONGITUDE","REGION","COLOR 1","COLOR 2"]]
stadiums_nfl_type_df.head()
# Out:
#             CITY                 TEAM    ROOF_TYPE  CAPACITY  LATITUDE  \
# 0       Glendale    Arizona Cardinals  Retractable   63400.0  33.52713
# 1        Oakland      Oakland Raiders         Open   63026.0  37.75233
# 2      San Diego   San Diego Chargers         Open   71294.0  32.78322
# 3  San Francisco  San Francisco 49ers         Open   70207.0  37.71399
# 4         Denver       Denver Broncos         Open   76125.0  39.74396
#
#    LONGITUDE REGION COLOR 1     COLOR 2
# 0 -112.25876   West   black      yellow
# 1 -122.19990   West  silver         NaN
# 2 -117.11976   West    gold  dodgerblue
# 3 -122.38673   West    gold         NaN
# 4 -105.02028   West    navy         NaN

# %%
# Merge two dataframes using a right join
#merge_stadiums_df = pd.merge(stadiums_nfl_df_type, stadiums_score_team_df, on="TEAM", how="right")
merge_stadiums_df = pd.merge(stadiums_score_df_2, stadiums_nfl_type_df, on="TEAM", how="right")
merge_stadiums_df
# Out:
#      Unnamed: 0 schedule_date  schedule_season                           TEAM  \
# 0       11076.0    09/04/2014           2014.0               Seattle Seahawks
# 1       11121.0    09/21/2014           2014.0               Seattle Seahawks
# 2       11163.0    10/12/2014           2014.0               Seattle Seahawks
# 3       11208.0    11/02/2014           2014.0               Seattle Seahawks
# 4       11220.0    11/09/2014           2014.0               Seattle Seahawks
# 5       11249.0    11/23/2014           2014.0               Seattle Seahawks
# 6       11297.0    12/14/2014           2014.0               Seattle Seahawks
# 7       11328.0    12/28/2014           2014.0               Seattle Seahawks
# 8       11387.0    09/27/2015           2015.0               Seattle Seahawks
# 9       11405.0    10/05/2015           2015.0               Seattle Seahawks
# 10      11431.0    10/18/2015           2015.0               Seattle Seahawks
# 11      11483.0    11/15/2015           2015.0               Seattle Seahawks
# 8           26.0         0.0        CenturyLink Field        W
# 9           13.0        10.0        CenturyLink Field        W
# 10          23.0        27.0        CenturyLink Field        L
# 11          32.0        39.0        CenturyLink Field        L
# 12          29.0        13.0        CenturyLink Field        W
# 13          39.0        30.0        CenturyLink Field        W
# 14          30.0        13.0        CenturyLink Field        W
# 15          17.0        23.0        CenturyLink Field        L
# 16          12.0        10.0        CenturyLink Field        W
# 17          37.0        18.0        CenturyLink Field        W
# 18          26.0        24.0        CenturyLink Field        W
# 19          31.0        25.0        CenturyLink Field        W
# 20          26.0        15.0        CenturyLink Field        W
# 21          40.0         7.0        CenturyLink Field        W
# 22          24.0         3.0        CenturyLink Field        W
# 23          31.0        34.0        CenturyLink Field        L
# 24          12.0         9.0        CenturyLink Field        W
# 25          46.0        17.0        CenturyLink Field        W
# 26          41.0        38.0        CenturyLink Field        W
# 27          14.0        17.0        CenturyLink Field        L
# 28          31.0        34.0        CenturyLink Field        L
# 29          24.0        10.0        CenturyLink Field        W
# ..           ...         ...                      ...      ...
# 845         27.0        34.0      Louisiana Superdome        L
# 846         10.0        41.0      Louisiana Superdome        L
# 847         14.0        30.0      Louisiana Superdome        L
# 848         19.0        26.0      Louisiana Superdome        L
# 849         26.0        20.0      Louisiana Superdome        W
# 850         31.0        21.0      Louisiana Superdome        W
# 851         52.0        49.0      Louisiana Superdome        W
# 852         28.0        34.0      Louisiana Superdome        L
# 853         38.0        41.0      Louisiana Superdome        L
# 854         27.0        35.0      Louisiana Superdome        L
# 855         38.0        27.0      Louisiana Superdome        W
# 856         34.0        35.0      Louisiana Superdome        L
# 857         32.0        45.0      Louisiana Superdome        L
# 858         41.0        38.0      Louisiana Superdome        W
# 859         25.0        20.0      Louisiana Superdome        W
# 860         23.0        25.0      Louisiana Superdome        L
# 861         49.0        21.0      Louisiana Superdome        W
# 862         13.0        28.0      Louisiana Superdome        L
# 863         31.0        24.0      Louisiana Superdome        W
# 864         20.0        36.0  Mercedes-Benz Superdome        L
# 865         52.0        38.0  Mercedes-Benz Superdome        W
# 866         20.0        12.0  Mercedes-Benz Superdome        W
# 867         30.0        10.0  Mercedes-Benz Superdome        W
# 868         34.0        31.0  Mercedes-Benz Superdome        W
# 869         31.0        21.0  Mercedes-Benz Superdome        W
# 870         31.0        19.0  Mercedes-Benz Superdome        W
# 871         23.0        13.0  Mercedes-Benz Superdome        W
# 872          NaN         NaN                      NaN      NaN
# 873          NaN         NaN                      NaN      NaN
# 874          NaN         NaN                      NaN      NaN
#
#                 CITY ROOF_TYPE  CAPACITY  LATITUDE  LONGITUDE      REGION  \
# 0            Seattle      Open   67000.0  47.59476 -122.33165        West
# 1            Seattle      Open   67000.0  47.59476 -122.33165        West
# 2            Seattle      Open   67000.0  47.59476 -122.33165        West
# 3            Seattle      Open   67000.0  47.59476 -122.33165        West
# 4            Seattle      Open   67000.0  47.59476 -122.33165        West
# 5            Seattle      Open   67000.0  47.59476 -122.33165        West
# 6            Seattle      Open   67000.0  47.59476 -122.33165        West
# 7            Seattle      Open   67000.0  47.59476 -122.33165        West
# 8            Seattle      Open   67000.0  47.59476 -122.33165        West
# 9            Seattle      Open   67000.0  47.59476 -122.33165        West
# 10           Seattle      Open   67000.0  47.59476 -122.33165        West
# 11           Seattle      Open   67000.0  47.59476 -122.33165        West
# 12           Seattle      Open   67000.0  47.59476 -122.33165        West
# 13           Seattle      Open   67000.0  47.59476 -122.33165        West
# 14           Seattle      Open   67000.0  47.59476 -122.33165        West
# 15           Seattle      Open   67000.0  47.59476 -122.33165        West
# 16           Seattle      Open   67000.0  47.59476 -122.33165        West
# 17           Seattle      Open   67000.0  47.59476 -122.33165        West
# 18           Seattle      Open   67000.0  47.59476 -122.33165        West
# 19           Seattle      Open   67000.0  47.59476 -122.33165        West
# 20           Seattle      Open   67000.0  47.59476 -122.33165        West
# 21           Seattle      Open   67000.0  47.59476 -122.33165        West
# 22           Seattle      Open   67000.0  47.59476 -122.33165        West
# 23           Seattle      Open   67000.0  47.59476 -122.33165        West
# 24           Seattle      Open   67000.0  47.59476 -122.33165        West
# 25           Seattle      Open   67000.0  47.59476 -122.33165        West
# 26           Seattle      Open   67000.0  47.59476 -122.33165        West
# 27           Seattle      Open   67000.0  47.59476 -122.33165        West
# 28           Seattle      Open   67000.0  47.59476 -122.33165        West
# 29           Seattle      Open   67000.0  47.59476 -122.33165        West
# ..               ...       ...       ...       ...        ...         ...
# 845      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 846      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 847      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 848      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 849      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 850      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 851      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 852      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 853      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 854      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 855      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 856      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 857      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 858      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 859      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 860      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 861      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 862      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 863      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 864      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 865      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 866      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 867      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 868      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 869      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 870      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 871      New Orleans      Dome   72968.0  29.95116  -90.08128       South
# 872            Miami       NaN       NaN  25.95801  -80.23889       South
# 873     Philadelphia       NaN       NaN  39.90147  -75.16729  North East
# 874  East Rutherford      Open   82500.0  40.81361  -74.07444  North East
#
#     COLOR 1     COLOR 2
# 0      gray  chartreuse
# 1      gray  chartreuse
# 2      gray  chartreuse
# 3      gray  chartreuse
# 4      gray  chartreuse
# 5      gray  chartreuse
# 6      gray  chartreuse
# 7      gray  chartreuse
# 8      gray  chartreuse
# 9      gray  chartreuse
# 10     gray  chartreuse
# 11     gray  chartreuse
# 12     gray  chartreuse
# 13     gray  chartreuse
# 14     gray  chartreuse
# 15     gray  chartreuse
# 16     gray  chartreuse
# 17     gray  chartreuse
# 18     gray  chartreuse
# 19     gray  chartreuse
# 20     gray  chartreuse
# 21     gray  chartreuse
# 22     gray  chartreuse
# 23     gray  chartreuse
# 24     gray  chartreuse
# 25     gray  chartreuse
# 26     gray  chartreuse
# 27     gray  chartreuse
# 28     gray  chartreuse
# 29     gray  chartreuse
# ..      ...         ...
# 845   black         NaN
# 846   black         NaN
# 847   black         NaN
# 848   black         NaN
# 849   black         NaN
# 850   black         NaN
# 851   black         NaN
# 852   black         NaN
# 853   black         NaN
# 854   black         NaN
# 855   black         NaN
# 856   black         NaN
# 857   black         NaN
# 858   black         NaN
# 859   black         NaN
# 860   black         NaN
# 861   black         NaN
# 862   black         NaN
# 863   black         NaN
# 864   black         NaN
# 865   black         NaN
# 866   black         NaN
# 867   black         NaN
# 868   black         NaN
# 869   black         NaN
# 870   black         NaN
# 871   black         NaN
# 872  orange        blue
# 873     NaN         NaN
# 874   white         NaN
#
# [875 rows x 16 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
stadiums_nfl_type_df.to_csv("stadiums_nfl_type.csv", index=False, header=True)

# %%
# Export file as a CSV, without the Pandas index, but with the header
merge_stadiums_df.to_csv("stadiums_nfl_merge.csv", index=False, header=True)
